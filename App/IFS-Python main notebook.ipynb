# %%
from ifs import *
plt.rcParams['figure.figsize'] = (16, 16)

# %% [markdown]
# ## Example 1: Sierpiński Gasket

# %%
# gasket().plot(n=5)  # one plot with n iterations
gasket().plot(grid=(3,3))  # successive iterations in a grid
plt.show()

# %% [markdown]
# ## Example 2: Fudgeflake

# %%
# fudgeflake().plot(n=5, facecolor='b')  # one plot with n iterations
fudgeflake().plot(grid = (3,3), facecolor = 'b')  # successive iterations in a grid
plt.show()

# %% [markdown]
# ## Example 3: Twindragon

# %%
# twindragon().plot(n=5, facecolor='w')  # one plot with n iterations
twindragon().plot(grid = (3,3), facecolor = 'w')  # successive iterations in a grid
plt.show()
