# %%
from ifs import *
plt.rcParams['figure.figsize'] = (16, 16)

# %% [markdown]
# ## Example 1: Sierpiński Gasket

# %%
gasket().plot(grid=(3,3))  
plt.show()

# %% [markdown]
# ## Example 2: Fudgeflake

# %%
fudgeflake().plot(grid = (3,3), facecolor = 'b')  
plt.show()

# %% [markdown]
# ## Example 3: Twindragon

# %%
twindragon().plot(grid = (3,3), facecolor = 'w')  
plt.show()
