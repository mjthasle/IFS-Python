# %%
import streamlit as st
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
from ifs import *

plt.rcParams['figure.figsize'] = (16, 16)

# %% [markdown]
# ## Example 1: Sierpiński Gasket

# %%
#Input the IFS functions    

t0 = mpl.transforms.Affine2D().scale(0.5)
t1 = mpl.transforms.Affine2D().translate(1, 0) + mpl.transforms.Affine2D().scale(0.5)
t2 = mpl.transforms.Affine2D().translate(0.5, np.sqrt(3)/2) + mpl.transforms.Affine2D().scale(0.5)

ifs = [t0, t1, t2]

#Input the vertices for the starting set

clicks = np.array([[0, 0], [1, 0], [0.5, np.sqrt(3)/2]])

#Plot the attractor 

#plot(ifs, clicks)  # starting set
#plot(ifs, clicks, n = 5)  # one plot with n iterations
fig = plot(ifs, clicks, grid = (3,3))  # successive iterations in a grid

#plt.show()
st.pyplot(fig)
# Out:
# 2023-06-12 22:00:08.306
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\mitch\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()

# %% [markdown]
# ## Example 2: Fudgeflake

# %%
#Input the IFS functions    

lamda = 1/np.sqrt(3)

t0 = mpl.transforms.Affine2D().rotate(np.pi/6) + mpl.transforms.Affine2D().scale(lamda) + mpl.transforms.Affine2D().translate(-1/3, 0)
t1 = mpl.transforms.Affine2D().rotate(np.pi/6) + mpl.transforms.Affine2D().scale(lamda) + mpl.transforms.Affine2D().translate(0.5*(1/3), (np.sqrt(3)/2)*(1/3))
t2 = mpl.transforms.Affine2D().rotate(np.pi/6) + mpl.transforms.Affine2D().scale(lamda) + mpl.transforms.Affine2D().translate(0.5*(1/3), -(np.sqrt(3)/2)*(1/3))

ifs = [t0, t1, t2]

#Input the vertices for the starting set

clicks = np.array([[0.2, 0.2], [1, 1], [0.75, 0.9], [0.2, 0.2], [0.75, 0.9], [0.5, 1]])
facecolor = 'b'
xlim = [-1,1]
ylim = xlim

#Plot the attractor 

#plot(ifs, clicks)  # starting set
#plot(ifs, clicks, n = 5)  # one plot with n iterations
plot(ifs, clicks, grid = (3,3), xlim = xlim, ylim = ylim, facecolor = facecolor)  # successive iterations in a grid
# Out:
# Iteration 0 took 0.0003045000000003739 seconds.
# Iteration 1 took 0.0014716999999997427 seconds.
# Iteration 2 took 0.004957100000000381 seconds.
# Iteration 3 took 0.01343409999999956 seconds.
# Iteration 4 took 0.03390219999999999 seconds.
# Iteration 5 took 0.545407299999999 seconds.
# Iteration 6 took 0.7424593000000002 seconds.
# Iteration 7 took 1.5020352999999993 seconds.
# Iteration 8 took 4.0393048 seconds.
# The whole cell took 8.545132099999998 seconds.

# %% [markdown]
# ## Example 3:

# %%
#Input the IFS functions    

lamda = 1/np.sqrt(2)

t0 = mpl.transforms.Affine2D().rotate(np.pi/4) + mpl.transforms.Affine2D().translate(-0.5, 0.5) + mpl.transforms.Affine2D().scale(lamda)
t1 = mpl.transforms.Affine2D().rotate(np.pi/4) + mpl.transforms.Affine2D().translate(0.5, -0.5) + mpl.transforms.Affine2D().scale(lamda)

ifs = [t0, t1]

#Input the vertices for the starting set

clicks = np.array([[0.2, 0.2], [1, 1], [0.75, 0.9], [0.2, 0.2], [0.75, 0.9], [0.5, 1]])
facecolor = 'w'
xlim = [-1.5, 1.5]
ylim = xlim

#Plot the attractor 

#plot(ifs, clicks)  # starting set
#plot(ifs, clicks, n = 5)  # one plot with n iterations
plot(ifs, clicks, grid = (4,3), xlim = xlim, ylim = ylim, facecolor = facecolor)  # successive iterations in a grid
# Out:
# Iteration 0 took 0.0003436000000007766 seconds.
# Iteration 1 took 0.0011641000000004453 seconds.
# Iteration 2 took 0.002732099999999349 seconds.
# Iteration 3 took 0.005316900000000402 seconds.
# Iteration 4 took 0.01003509999999963 seconds.
# Iteration 5 took 0.45572569999999857 seconds.
# Iteration 6 took 0.48085809999999896 seconds.
# Iteration 7 took 0.5161645999999998 seconds.
# Iteration 8 took 0.596787599999999 seconds.
# Iteration 9 took 0.7604129999999998 seconds.
# Iteration 10 took 1.1536432000000012 seconds.
# Iteration 11 took 2.0060319 seconds.
# The whole cell took 4.267389399999999 seconds.
